# %% [markdown]
# <a href="https://colab.research.google.com/github/24Priyanshi/OpenCV-Practice/blob/main/opencv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

# %%
import cv2
import numpy as np

# %%
list_name= os.listdir('/content/drive/MyDrive/Opencv')
list_name
# Out:
# ['.ipynb_checkpoints', 'doggu.jpg', 'billu.jpg', 'moodeng.jpg']

# %%
from google.colab.patches import cv2_imshow

# %%
for name in list_name:
  path="/content/drive/MyDrive/Opencv"
  img_name=path+"/"+name
  img=cv2.imread(img_name)
  img=cv2.resize(img,(200,200))
  cv2_imshow(img)
  cv2.waitKey(5000)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200>
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-21-1a59bd5ac0a3> in <cell line: 0>()
#       3   img_name=path+"/"+name
#       4   img=cv2.imread(img_name)
# ----> 5   img=cv2.resize(img,(200,200))
#       6   cv2_imshow(img)
#       7   cv2.waitKey(5000)
#
# error: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'

# %%
for name in list_name:
    path = "/content/drive/MyDrive/Opencv"
    img_name = path + "/" + name
    img = cv2.imread(img_name)

    if img is None:
        print(f"Error loading image: {img_name}")
        continue  # Skip this image and move to the next one

    img = cv2.resize(img, (200, 200))
    cv2.imshow("Image", img)
    cv2.waitKey(5000)
# Out:
# Error loading image: /content/drive/MyDrive/Opencv/.ipynb_checkpoints
# ---------------------------------------------------------------------------
# DisabledFunctionError                     Traceback (most recent call last)
# <ipython-input-9-65faa2acf141> in <cell line: 0>()
#       9
#      10     img = cv2.resize(img, (200, 200))
# ---> 11     cv2.imshow("Image", img)
#      12     cv2.waitKey(5000)
#
# /usr/local/lib/python3.11/dist-packages/google/colab/_import_hooks/_cv2.py in wrapped(*args, **kwargs)
#      46   def wrapped(*args, **kwargs):
#      47     if not os.environ.get(env_var, False):
# ---> 48       raise DisabledFunctionError(message, name or func.__name__)
#      49     return func(*args, **kwargs)
#      50
#
# DisabledFunctionError: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
