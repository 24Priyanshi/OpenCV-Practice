# %% [markdown]
# <a href="https://colab.research.google.com/github/24Priyanshi/OpenCV-Practice/blob/main/newopencv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

# %%
img= cv2.imread("billu.jpg")
print(img)
print(img.shape)
# Out:
# [[[31 25 20]
#   [31 25 20]
#   [31 25 20]
#   ...
#   [37 36 22]
#   [37 36 22]
#   [38 37 23]]
#
#  [[31 25 20]
#   [31 25 20]
#   [31 25 20]
#   ...
#   [37 36 22]
#   [37 36 22]
#   [38 37 23]]
#
#  [[31 25 20]
#   [31 25 20]
#   [31 25 20]
#   ...
#   [37 35 24]
#   [37 36 22]
#   [38 37 23]]
#
#  ...
#
#  [[39 34 36]
#   [39 34 36]
#   [39 34 36]
#   ...
#   [41 40 26]
#   [41 40 26]
#   [42 41 27]]
#
#  [[38 33 35]
#   [38 33 35]
#   [38 33 35]
#   ...
#   [41 40 26]
#   [42 41 27]
#   [42 41 27]]
#
#  [[37 32 34]
#   [37 32 34]
#   [37 32 34]
#   ...
#   [41 40 26]
#   [42 41 27]
#   [42 41 27]]]
# (799, 640, 3)

# %%
from google.colab.patches import cv2_imshow

# %%
img=cv2.resize(img,(500,500))
cv2_imshow(img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=500x500>

# %%
img= cv2.imread("billu.jpg",0)
img=cv2.resize(img,(500,500))
cv2_imshow(img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=L size=500x500>

# %%
img= cv2.imread("billu.jpg",-1)
img=cv2.resize(img,(500,500))
cv2_imshow(img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=500x500>

# %%
img_get=cv2.imread('doggu.jpg')
img=img_get
text="How're you?"

txt=cv2.putText('')

cv2_imshow(img_get)
cv2.waitKey(0)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-26-97f83cea7ee8> in <cell line: 0>()
#       2 img=img_get
#       3 text="How're you?"
# ----> 4 txt=cv2.putText('')
#       5
#       6 cv2_imshow(img_get)
#
# error: OpenCV(4.11.0) :-1: error: (-5:Bad argument) in function 'putText'
# > Overload resolution failed:
# >  - putText() missing required argument 'text' (pos 2)
# >  - putText() missing required argument 'text' (pos 2)

# %%
img_get=cv2_imread('doggu.jpg',0)
